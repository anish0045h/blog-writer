# %%
pip install langchain langgraph langchain-groq langchain-community tavily-search python-dotenv
# Out:
# Collecting langchain
#   Using cached langchain-1.2.15-py3-none-any.whl (112 kB)
# Collecting langgraph
#   Using cached langgraph-1.1.6-py3-none-any.whl (169 kB)
# Collecting langchain-groq
#   Using cached langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Collecting langchain-community
#   Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tavily-search (from versions: none)
# ERROR: No matching distribution found for tavily-search
#
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pydantic
# Out:
# Collecting pydantic
#   Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#      -------------------------------------- 463.6/463.6 kB 1.4 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.41.5
#   Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 545.0 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\anish\appdata\roaming\python\python311\site-packages (from pydantic) (4.15.0)
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pydantic-core, annotated-types, pydantic
# Successfully installed annotated-types-0.7.0 pydantic-2.12.5 pydantic-core-2.41.5 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install langgraph
# Out:
# Collecting langgraph
#   Using cached langgraph-1.1.6-py3-none-any.whl (169 kB)
# Collecting langchain-core>=0.1
#   Downloading langchain_core-1.2.26-py3-none-any.whl (508 kB)
#      -------------------------------------- 508.3/508.3 kB 3.5 MB/s eta 0:00:00
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0
#   Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.5/50.5 kB 1.3 MB/s eta 0:00:00
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9
#   Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl (35 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0
#   Downloading langgraph_sdk-0.3.12-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.8/95.8 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langgraph) (2.12.5)
# Collecting xxhash>=3.5.0
#   Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl (31 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<1.0.0,>=0.3.45
#   Downloading langsmith-0.7.25-py3-none-any.whl (359 kB)
#      -------------------------------------- 359.4/359.4 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=23.2.0 in c:\users\anish\appdata\roaming\python\python311\site-packages (from langchain-core>=0.1->langgraph) (26.0)
# Collecting pyyaml<7.0.0,>=5.3.0
#   Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
#      -------------------------------------- 158.8/158.8 kB 2.4 MB/s eta 0:00:00
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0
#   Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\anish\appdata\roaming\python\python311\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
#      -------------------------------------- 187.1/187.1 kB 2.8 MB/s eta 0:00:00
# Collecting ormsgpack>=1.12.0
#   Downloading ormsgpack-1.12.2-cp311-cp311-win_amd64.whl (117 kB)
#      -------------------------------------- 117.2/117.2 kB 3.4 MB/s eta 0:00:00
# Collecting httpx>=0.25.2
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ---------------------------------------- 73.5/73.5 kB 2.0 MB/s eta 0:00:00
# Collecting orjson>=3.11.5
#   Downloading orjson-3.11.8-cp311-cp311-win_amd64.whl (127 kB)
#      -------------------------------------- 127.4/127.4 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Collecting anyio
#   Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
#      -------------------------------------- 114.4/114.4 kB 3.3 MB/s eta 0:00:00
# Collecting certifi
#   Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
#      -------------------------------------- 153.7/153.7 kB 3.1 MB/s eta 0:00:00
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.8/78.8 kB 2.2 MB/s eta 0:00:00
# Collecting idna
#   Downloading idna-3.11-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.0/71.0 kB 1.9 MB/s eta 0:00:00
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Collecting requests-toolbelt>=1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ---------------------------------------- 54.5/54.5 kB 2.9 MB/s eta 0:00:00
# Collecting requests>=2.0.0
#   Downloading requests-2.33.1-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.9/64.9 kB 1.8 MB/s eta 0:00:00
# Collecting zstandard>=0.23.0
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
#      -------------------------------------- 506.2/506.2 kB 2.4 MB/s eta 0:00:00
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.7-cp311-cp311-win_amd64.whl (159 kB)
#      -------------------------------------- 159.3/159.3 kB 1.9 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.26
#   Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
#      -------------------------------------- 131.6/131.6 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: zstandard, xxhash, uuid-utils, urllib3, tenacity, pyyaml, ormsgpack, orjson, jsonpointer, idna, h11, charset_normalizer, certifi, requests, jsonpatch, httpcore, anyio, requests-toolbelt, httpx, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph
# Successfully installed anyio-4.13.0 certifi-2026.2.25 charset_normalizer-3.4.7 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jsonpatch-1.33 jsonpointer-3.1.1 langchain-core-1.2.26 langgraph-1.1.6 langgraph-checkpoint-4.0.1 langgraph-prebuilt-1.0.9 langgraph-sdk-0.3.12 langsmith-0.7.25 orjson-3.11.8 ormsgpack-1.12.2 pyyaml-6.0.3 requests-2.33.1 requests-toolbelt-1.0.0 tenacity-9.1.4 urllib3-2.6.3 uuid-utils-0.14.1 xxhash-3.6.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\anish\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\anish\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Using cached langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Collecting groq<1.0.0,>=0.30.0
#   Downloading groq-0.37.1-py3-none-any.whl (137 kB)
#      -------------------------------------- 137.5/137.5 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-groq) (1.2.26)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.13.0)
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.5)
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\anish\appdata\roaming\python\python311\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.7.25)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\anish\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.14.1)
# Requirement already satisfied: idna>=2.8 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.11)
# Requirement already satisfied: certifi in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (2.6.3)
# Installing collected packages: sniffio, distro, groq, langchain-groq
# Successfully installed distro-1.9.0 groq-0.37.1 langchain-groq-1.1.2 sniffio-1.3.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script distro.exe is installed in 'c:\Users\anish\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (1.2.26)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.33.1)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.7.25)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\anish\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\anish\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.14.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.2.25)
# Requirement already satisfied: greenlet>=1 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: anyio in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.13.0)
# Requirement already satisfied: httpcore==1.* in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\anish\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from __future__ import annotations

import operator
import os
import re
from datetime import date, datetime, timedelta
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send
from langchain_groq import ChatGroq

from langchain_core.messages import SystemMessage, HumanMessage
#from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    groq_api_key="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"
)

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str

    # NEW: tells workers what genre this is (prevents drift)
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"

    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # prefer ISO "YYYY-MM-DD"
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    reason: str
    queries: List[str] = Field(default_factory=list)
    max_results_per_query: int = Field(5, description="How many results to fetch per query (3–8).")


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # NEW: recency control
    as_of: str           # ISO date, e.g. "2026-01-29"
    recency_days: int    # 7 for weekly news, 30 for hybrid, etc.

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)
    final: str

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- For open_book weekly roundup, include queries that reflect the last 7 days constraint.
"""

def router_node(state: State) -> dict:
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}\nAs-of date: {state['as_of']}"),
        ]
    )

    # Set default recency window based on mode
    if decision.mode == "open_book":
        recency_days = 7
    elif decision.mode == "hybrid":
        recency_days = 45
    else:
        recency_days = 3650

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
        "recency_days": recency_days,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily)
# -----------------------------
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    """
    Uses TavilySearchResults if installed and TAVILY_API_KEY is set.
    Returns list of dict with common fields. Note: published date is often missing.
    """
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


def _iso_to_date(s: Optional[str]) -> Optional[date]:
    if not s:
        return None
    try:
        return date.fromisoformat(s[:10])
    except Exception:
        return None


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- Extract/normalize published_at as ISO (YYYY-MM-DD) if you can infer it from title/snippet.
  If you can't infer a date reliably, set published_at=null (do NOT guess).
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:
    queries = (state.get("queries", []) or [])[:10]
    max_results = 6

    raw_results: List[dict] = []
    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(
                content=(
                    f"As-of date: {state['as_of']}\n"
                    f"Recency days: {state['recency_days']}\n\n"
                    f"Raw results:\n{raw_results}"
                )
            ),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e
    evidence = list(dedup.values())

    # HARD RECENCY FILTER for open_book weekly roundup:
    # keep only items with a parseable ISO date and within the window.
    mode = state.get("mode", "closed_book")
    if mode == "open_book":
        as_of = date.fromisoformat(state["as_of"])
        cutoff = as_of - timedelta(days=int(state["recency_days"]))
        fresh: List[EvidenceItem] = []
        for e in evidence:
            d = _iso_to_date(e.published_at)
            if d and d >= cutoff:
                fresh.append(e)
        evidence = fresh

    return {"evidence": evidence}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Flexibility:
- Do NOT use a fixed taxonomy unless it naturally fits.
- You may tag tasks (tags field), but tags are flexible.

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book (weekly news roundup):
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections (no scraping/RSS/how to fetch news) unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient fresh sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)
    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    # Force blog_kind for open_book
    forced_kind = "news_roundup" if mode == "open_book" else None

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {state['as_of']} (recency_days={state['recency_days']})\n"
                    f"{'Force blog_kind=news_roundup' if forced_kind else ''}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}\n\n"
                    f"Instruction: If mode=open_book, your plan must NOT drift into a tutorial."
                )
            ),
        ]
    )

    # Ensure open_book forces the kind even if model forgets
    if forced_kind:
        plan.blog_kind = "news_roundup"

    return {"plan": plan}


# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    assert state["plan"] is not None
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "as_of": state["as_of"],
                "recency_days": state["recency_days"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard (prevents mid-blog topic drift):
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book (weekly news):
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true (hybrid sections):
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning (concepts, intuition) is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")
    as_of = payload.get("as_of")
    recency_days = payload.get("recency_days")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    # Provide a compact evidence list for citation use
    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {as_of} (recency_days={recency_days})\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    # deterministic ordering
    return {"sections": [(task.id, section_md)]}

# %%
# -----------------------------
# 8) Reducer (merge + save)
# -----------------------------
def reducer_node(state: State) -> dict:
    plan = state["plan"]
    if plan is None:
        raise ValueError("Reducer called without a plan.")

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 9) Build graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,   # router may overwrite
            "sections": [],
            "final": "",
        }
    )

    plan: Plan = out["plan"]
    print("\n" + "=" * 100)
    print("TOPIC:", topic)
    print("AS_OF:", out.get("as_of"), "RECENCY_DAYS:", out.get("recency_days"))
    print("MODE:", out.get("mode"))
    print("BLOG_KIND:", plan.blog_kind)
    print("NEEDS_RESEARCH:", out.get("needs_research"))
    print("QUERIES:", (out.get("queries") or [])[:6])
    print("EVIDENCE_COUNT:", len(out.get("evidence", [])))
    if out.get("evidence"):
        print("EVIDENCE_SAMPLE:", [e.model_dump() for e in out["evidence"][:2]])
    print("TASKS:", len(plan.tasks))
    print("SAVED_MD_CHARS:", len(out.get("final", "")))
    print("=" * 100 + "\n")

    return out

# %%
run("Write a blog on Self Attention")
# Out:
# ====================================================================================================
# TOPIC: Write a blog on Self Attention
# AS_OF: 2026-04-05 RECENCY_DAYS: 3650
# MODE: closed_book
# BLOG_KIND: explainer
# NEEDS_RESEARCH: False
# QUERIES: []
# EVIDENCE_COUNT: 0
# TASKS: 8
# SAVED_MD_CHARS: 8365
# ====================================================================================================
# {'topic': 'Write a blog on Self Attention',
#  'mode': 'closed_book',
#  'needs_research': False,
#  'queries': [],
#  'evidence': [],
#  'plan': Plan(blog_title='Understanding Self Attention', audience='developers', tone='technical', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='Introduction to Self Attention', goal='The reader should understand the concept of self attention and its importance in deep learning models.', bullets=['Define self attention and its role in transformer architectures', 'Explain the difference between self attention and traditional attention mechanisms', 'Discuss the benefits of using self attention in natural language processing tasks'], target_words=200, tags=['self attention', 'transformer architectures'], requires_research=False, requires_citations=False, requires_code=False), Task(id=2, title='Mathematical Formulation of Self Attention', goal='The reader should be able to understand the mathematical formulation of self attention and its components.', bullets=['Explain the query-key-value formulation of self attention', 'Discuss the role of attention weights and their calculation', 'Describe the multi-head attention mechanism'], target_words=300, tags=['self attention', 'mathematical formulation'], requires_research=False, requires_citations=False, requires_code=False), Task(id=3, title='Self Attention in Transformer Architectures', goal='The reader should understand how self attention is used in transformer architectures and its advantages.', bullets=['Describe the encoder-decoder structure of transformer models', 'Explain how self attention is used in the encoder and decoder', 'Discuss the advantages of using self attention in transformer models'], target_words=250, tags=['transformer architectures', 'self attention'], requires_research=False, requires_citations=False, requires_code=False), Task(id=4, title='Edge Cases and Failure Modes', goal='The reader should be aware of the potential edge cases and failure modes of self attention mechanisms.', bullets=['Discuss the impact of long-range dependencies on self attention', 'Explain the effect of sparse attention on model performance', 'Describe the potential failure modes of self attention in certain tasks'], target_words=200, tags=['edge cases', 'failure modes'], requires_research=False, requires_citations=False, requires_code=False), Task(id=5, title='Code Implementation of Self Attention', goal='The reader should be able to implement a basic self attention mechanism using a deep learning framework.', bullets=['Provide a minimal code sketch of self attention using a popular deep learning framework', 'Explain the key components of the implementation', 'Discuss the importance of hyperparameter tuning in self attention models'], target_words=250, tags=['code implementation', 'self attention'], requires_research=False, requires_citations=False, requires_code=True), Task(id=6, title='Performance and Cost Considerations', goal='The reader should understand the performance and cost considerations of self attention mechanisms.', bullets=['Discuss the computational complexity of self attention', 'Explain the memory requirements of self attention models', 'Describe the potential optimization techniques for self attention models'], target_words=200, tags=['performance', 'cost considerations'], requires_research=False, requires_citations=False, requires_code=False), Task(id=7, title='Security and Privacy Considerations', goal='The reader should be aware of the security and privacy considerations of self attention mechanisms.', bullets=['Discuss the potential security risks of self attention models', 'Explain the importance of data privacy in self attention models', 'Describe the potential mitigation techniques for security and privacy risks'], target_words=200, tags=['security', 'privacy considerations'], requires_research=False, requires_citations=False, requires_code=False), Task(id=8, title='Debugging and Observability Tips', goal='The reader should be able to debug and observe self attention models effectively.', bullets=['Provide tips for debugging self attention mode ...
#  'as_of': '2026-04-05',
#  'recency_days': 3650,
#  'sections': [(1,
#    '## Introduction to Self Attention\nSelf attention is a key component in transformer architectures, enabling models to weigh the importance of different input elements relative to each other. It plays a crucial role in processing sequential data, such as text or time series data, by allowing the model to attend to all positions in the input sequence simultaneously and weigh their importance.\n\n* Self attention is defined as a mechanism that allows a model to attend to all positions in the input sequence and compute a representation of the input sequence based on the relative importance of each position.\n* In contrast to traditional attention mechanisms, self attention does not rely on a separate encoder and decoder, but instead uses a single sequence as both the input and output, allowing it to capture long-range dependencies more effectively.\n* The benefits of using self attention in natural language processing tasks include improved parallelization, reduced computational complexity, and enhanced ability to capture nuanced contextual relationships between input elements, leading to state-of-the-art results in many NLP tasks.'),
#   (2,
#    '## Mathematical Formulation of Self Attention\nThe self attention mechanism is a crucial component of transformer models, allowing them to weigh the importance of different input elements relative to each other. At its core, self attention operates on a query-key-value formulation. \n* The query-key-value formulation of self attention involves three main vectors: query (Q), key (K), and value (V). These vectors are derived from the input data and are used to compute attention weights.\n* The role of attention weights is to determine the relevance of each input element to every other element. These weights are calculated by taking the dot product of the query and key vectors and applying a scaling factor, followed by a softmax function to normalize the weights.\n* The multi-head attention mechanism extends the basic self attention concept by applying it multiple times in parallel, with different linear projections of the input data. This allows the model to capture different types of relationships between input elements, improving its overall representational power. The outputs from each attention head are then concatenated and linearly transformed to produce the final output. This multi-head mechanism helps to increase the capacity and robustness of the self attention mechanism, enabling it to handle complex input data more effectively.'),
#   (3,
#    '## Self Attention in Transformer Architectures\nTransformer architectures are composed of an encoder-decoder structure, where the encoder takes in a sequence of tokens and generates a continuous representation, and the decoder generates the output sequence. \n* The encoder consists of a stack of identical layers, each comprising two sub-layers: self-attention and feed-forward neural networks.\n* The decoder also consists of a stack of identical layers, each comprising three sub-layers: self-attention, encoder-decoder attention, and feed-forward neural networks.\n\nSelf attention is used in both the encoder and decoder to allow the model to attend to different parts of the input sequence and weigh their importance. \nIn the encoder, self attention is used to compute the representation of the input sequence, while in the decoder, self attention is used to compute the representation of the output sequence.\n\nThe advantages of using self attention in transformer models include parallelization of sequential computations, reduction of computational complexity, and the ability to handle long-range dependencies. \nThis allows transformer models to be more efficient and effective in handling sequential data, making them a popular choice for many natural language processing tasks.'),
#   (4,
#    '## Edge Cases and Failure Modes\nSelf attention mechanisms can be sensitive to certain edge cases and failure modes. \n* The impact of long-range dependencies on self attention can be significant, as the mechanism may struggle to capture relationships between distant elements in a sequence.\n* Sparse attention, where only a subset of the input elements are attended to, can affect model performance by reducing the amount of contextual information available.\n* Self attention can fail in certain tasks, such as those requiring strict locality or hierarchical relationships, due to its inherent assumption of global interaction between elements.'),
#   (5,
#    "## Code Implementation of Self Attention\nTo implement a basic self attention mechanism, we can use a popular deep learning framework such as PyTorch. Here's a minimal code sketch:\n```python\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\n\nclass SelfAttention(nn.Module):\n    def __init__(self, embed_dim, num_heads):\n        super(SelfAttention, self).__init__()\n        self.query_linear = nn.Linear(embed_dim, embed_dim)\n        self.key_linear = nn.Linear(embed_dim, embed_dim)\n        self.value_linear = nn.Linear(embed_dim, embed_dim)\n        self.dropout = nn.Dropout(0.1)\n\n    def forward(self, x):\n        query = self.query_linear(x)\n        key = self.key_linear(x)\n        value = self.value_linear(x)\n        attention_scores = torch.matmul(query, key.T) / math.sqrt(x.size(-1))\n        attention_weights = F.softmax(attention_scores, dim=-1)\n        attention_output = torch.matmul(attention_weights, value)\n        return attention_output\n```\nThe key components of this implementation are the query, key, and value linear layers, which transform the input into the necessary vectors for self attention. The `forward` method computes the attention scores, weights, and output. \n* The importance of hyperparameter tuning in self attention models cannot be overstated, as it directly affects the performance of the model. Hyperparameters such as the number of heads, embedding dimension, and dropout rate need to be carefully tuned for optimal results."),
#   (6,
#    '## Performance and Cost Considerations\nThe self attention mechanism, while powerful, comes with significant performance and cost considerations. \n* Discussing the computational complexity of self attention: self attention has a computational complexity of O(n^2), where n is the sequence length, due to the dot-product attention mechanism.\n* The memory requirements of self attention models are also substantial, as they require storing the attention weights and the input sequences, making them memory-intensive.\n* To mitigate these costs, several optimization techniques can be employed, such as sparse attention, attention pruning, or using approximate attention mechanisms, which can reduce the computational complexity and memory requirements of self attention models.'),
#   (7,
#    "## Security and Privacy Considerations\nSelf attention models, like other deep learning architectures, are not immune to security and privacy risks. \n* Potential security risks of self attention models include adversarial attacks, which can compromise the integrity of the model's outputs.\n* Data privacy is crucial in self attention models, as they often process sensitive information, such as user data or confidential text.\nTo mitigate these risks, several techniques can be employed, including:\n* Implementing robust adversarial training methods\n* Using differential privacy to protect sensitive information\n* Regularly updating and patching models to prevent exploitation of known vulnerabilities."),
#   (8,
#    "## Debugging and Observability Tips\nTo effectively debug self attention models, several tips can be employed. \n*   Check the input data for any inconsistencies or incorrect formatting, as self attention models can be sensitive to such issues.\n*   Monitor the model's performance on a validation set during training to catch any potential overfitting or underfitting.\n\nThe importance of visualization in self attention models cannot be overstated. By visualizing the attention weights, developers can gain insight into which parts of the input data the model is focusing on, helping to identify potential issues.\n\nFor observability in self attention models, several tools and techniques can be utilized. These include using TensorBoard or other visualization libraries to track model performance and attention weights over time, as well as implementing custom logging or callback functions to monitor specific aspects of the model's behavior.")],
#  'final': "# Understanding Self Attention\n\n## Introduction to Self Attention\nSelf attention is a key component in transformer architectures, enabling models to weigh the importance of different input elements relative to each other. It plays a crucial role in processing sequential data, such as text or time series data, by allowing the model to attend to all positions in the input sequence simultaneously and weigh their importance.\n\n* Self attention is defined as a mechanism that allows a model to attend to all positions in the input sequence and compute a representation of the input sequence based on the relative importance of each position.\n* In contrast to traditional attention mechanisms, self attention does not rely on a separate encoder and decoder, but instead uses a single sequence as both the input and output, allowing it to capture long-range dependencies more effectively.\n* The benefits of using self attention in natural language processing tasks include improved parallelization, reduced computational complexity, and enhanced ability to capture nuanced contextual relationships between input elements, leading to state-of-the-art results in many NLP tasks.\n\n## Mathematical Formulation of Self Attention\nThe self attention mechanism is a crucial component of transformer models, allowing them to weigh the importance of different input elements relative to each other. At its core, self attention operates on a query-key-value formulation. \n* The query-key-value formulation of self attention involves three main vectors: query (Q), key (K), and value (V). These vectors are derived from the input data and are used to compute attention weights.\n* The role of attention weights is to determine the relevance of each input element to every other element. These weights are calculated by taking the dot product of the query and key vectors and applying a scaling factor, followed by a softmax function to normalize the weights.\n* The multi-head attention mechanism extends the basic self attention concept by applying it multiple times in parallel, with different linear projections of the input data. This allows the model to capture different types of relationships between input elements, improving its overall representational power. The outputs from each attention head are then concatenated and linearly transformed to produce the final output. This multi-head mechanism helps to increase the capacity and robustness of the self attention mechanism, enabling it to handle complex input data more effectively.\n\n## Self Attention in Transformer Architectures\nTransformer architectures are composed of an encoder-decoder structure, where the encoder takes in a sequence of tokens and generates a continuous representation, and the decoder generates the output sequence. \n* The encoder consists of a stack of identical layers, each comprising two sub-layers: self-attention and feed-forward neural networks.\n* The decoder also consists of a stack of identical layers, each comprising three sub-layers: self-attention, encoder-decoder attention, and feed-forward neural networks.\n\nSelf attention is used in both the encoder and decoder to allow the model to attend to different parts of the input sequence and weigh their importance. \nIn the encoder, self attention is used to compute the representation of the input sequence, while in the decoder, self attention is used to compute the representation of the output sequence.\n\nThe advantages of using self attention in transformer models include parallelization of sequential computations, reduction of computational complexity, and the ability to handle long-range dependencies. \nThis allows transformer models to be more efficient and effective in handling sequential data, making them a popular choice for many natural language processing tasks.\n\n## Edge Cases and Failure Modes\nSelf attention mechanisms can be sensitive to certain edge cases and failure modes. \n* The impact of long-range de ...
